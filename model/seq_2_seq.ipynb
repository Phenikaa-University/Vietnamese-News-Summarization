# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import time
import re
import pickle
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/drive/MyDrive/Phenikaa University/Introduction NLP/news-mds-extractive_008.csv")

# %%
df.head()
# Out:
#                                             document  \
# 0  quân đội israel tuyên bố phát hiện đường hầm h...
# 1  nhiều bố mẹ ngại mang tiếng giữ dùm, nên để co...
# 2  uaequần đảo hình cây cọ palm jumeirah rộng 5,7...
# 3  ông trump quyết tâm trở lại nhà trắng song kết...
# 4  vaccine alloy-ek được nghiên cứu để ngăn tình ...
#
#                                              summary  \
# 0  trong video do quân đội israel công bố ngày 7/...
# 1  trong năm học, các bậc phụ huynh nên giải thíc...
# 2  các kỹ sư xây dựng loạt đảo nhân tạo lớn nhất ...
# 3  trong cuộc bầu cử năm 2016, cựu tổng thống don...
# 4  các bác sĩ khoa học và tài chính tại minnesota...
#
#                                   extractive_summary
# 0  quân đội israel tuyên bố phát hiện đường hầm h...
# 1  nhiều bố mẹ ngại mang tiếng giữ dùm, nên để co...
# 2  uaequần đảo hình cây cọ palm jumeirah rộng 5,7...
# 3  ông trump quyết tâm trở lại nhà trắng song kết...
# 4  vaccine alloy-ek được nghiên cứu để ngăn tình ...

# %%
import torch
USE_GPU = torch.cuda.is_available()
print('USE_GPU={}'.format(USE_GPU))
if USE_GPU:
    print('current_device={}'.format(torch.cuda.current_device()))
# Out:
# USE_GPU=True
# current_device=0

# %%
document = df['extractive_summary']
summary = df['summary']

# %%
# for decoder sequence
summary = summary.apply(lambda x: '<go> ' + x + ' <stop>')
summary.head()
# Out:
# 0    <go> trong video do quân đội israel công bố ng...
# 1    <go> trong năm học, các bậc phụ huynh nên giải...
# 2    <go> các kỹ sư xây dựng loạt đảo nhân tạo lớn ...
# 3    <go> trong cuộc bầu cử năm 2016, cựu tổng thốn...
# 4    <go> các bác sĩ khoa học và tài chính tại minn...
# Name: summary, dtype: object

# %%
# since < and > from default tokens cannot be removed
filters = '!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n'
oov_token = '<unk>'

# %%
document_tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token=oov_token)
summary_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters=filters, oov_token=oov_token)

# %%
document_tokenizer.fit_on_texts(document)
summary_tokenizer.fit_on_texts(summary)

# %%
inputs = document_tokenizer.texts_to_sequences(document)
targets = summary_tokenizer.texts_to_sequences(summary)

# %%
summary_tokenizer.texts_to_sequences(['tác một tại nam'])
# Out:
# [[184, 22, 12, 71]]

# %%
summary_tokenizer.sequences_to_texts([[184, 22, 12, 71]])
# Out:
# ['tác một tại nam']

# %%
encoder_vocab_size = len(document_tokenizer.word_index) + 1
decoder_vocab_size = len(summary_tokenizer.word_index) + 1

# vocab_size
encoder_vocab_size, decoder_vocab_size
# Out:
# (3987, 1199)

# %%
document_lengths = pd.Series([len(x) for x in document])
summary_lengths = pd.Series([len(x) for x in summary])

# %%
document_lengths.describe()
# Out:
# count     100.000000
# mean     2859.070000
# std       608.272156
# min      1651.000000
# 25%      2566.000000
# 50%      2831.000000
# 75%      3176.500000
# max      5232.000000
# dtype: float64

# %%
summary_lengths.describe()
# Out:
# count    100.000000
# mean     263.630000
# std       53.231087
# min      193.000000
# 25%      226.250000
# 50%      255.500000
# 75%      284.500000
# max      593.000000
# dtype: float64

# %%
# maxlen
# taking values > and round figured to 75th percentile
# at the same time not leaving high variance
encoder_maxlen = 3500
decoder_maxlen = 300

# %%
inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs, maxlen=encoder_maxlen, padding='post', truncating='post')
targets = tf.keras.preprocessing.sequence.pad_sequences(targets, maxlen=decoder_maxlen, padding='post', truncating='post')

# %%
inputs = tf.cast(inputs, dtype=tf.int32)
targets = tf.cast(targets, dtype=tf.int32)

# %%
BUFFER_SIZE = 20000
BATCH_SIZE = 1

# %%
dataset = tf.data.Dataset.from_tensor_slices((inputs, targets)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def get_angles(position, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return position * angle_rates

# %%
def positional_encoding(position, d_model):
    angle_rads = get_angles(
        np.arange(position)[:, np.newaxis],
        np.arange(d_model)[np.newaxis, :],
        d_model
    )

    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]

# %%
def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask

# %%
def scaled_dot_product_attention(q, k, v, mask):
    matmul_qk = tf.matmul(q, k, transpose_b=True)

    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    if mask is not None:
        scaled_attention_logits += (mask * -1e9)

    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)

    output = tf.matmul(attention_weights, v)
    return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]

        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)

        scaled_attention, attention_weights = scaled_dot_product_attention(
            q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model))
        output = self.dense(concat_attention)

        return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),
        tf.keras.layers.Dense(d_model)
    ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        attn_output, _ = self.mha(x, x, x, mask)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)

        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(d_model, num_heads)
        self.mha2 = MultiHeadAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)


    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)

        ffn_output = self.ffn(out2)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)

        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, self.d_model)

        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]

        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        seq_len = tf.shape(x)[1]

        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training, mask)

        return x

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size, maximum_position_encoding, rate=0.1):
        super(Decoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        seq_len = tf.shape(x)[1]
        attention_weights = {}

        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x, block1, block2 = self.dec_layers[i](x, enc_output, training, look_ahead_mask, padding_mask)

            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

        return x, attention_weights

# %%
class Transformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, target_vocab_size, pe_input, pe_target, rate=0.1):
        super(Transformer, self).__init__()

        self.encoder = Encoder(num_layers, d_model, num_heads, dff, input_vocab_size, pe_input, rate)

        self.decoder = Decoder(num_layers, d_model, num_heads, dff, target_vocab_size, pe_target, rate)

        self.final_layer = tf.keras.layers.Dense(target_vocab_size)

    def call(self, inp, tar, training, enc_padding_mask, look_ahead_mask, dec_padding_mask):
        enc_output = self.encoder(inp, training, enc_padding_mask)

        dec_output, attention_weights = self.decoder(tar, enc_output, training, look_ahead_mask, dec_padding_mask)

        final_output = self.final_layer(dec_output)

        return final_output, attention_weights

# %%
# hyper-params
num_layers = 4
d_model = 128
dff = 512
num_heads = 8
EPOCHS = 20

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps

    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate==0.01, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')

# %%
transformer = Transformer(
    num_layers,
    d_model,
    num_heads,
    dff,
    encoder_vocab_size,
    decoder_vocab_size,
    pe_input=encoder_vocab_size,
    pe_target=decoder_vocab_size,
)

# %%
def create_masks(inp, tar):
    enc_padding_mask = create_padding_mask(inp)
    dec_padding_mask = create_padding_mask(inp)

    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = create_padding_mask(tar)
    combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return enc_padding_mask, combined_mask, dec_padding_mask

# %%
checkpoint_path = "/content/drive/MyDrive/Phenikaa University/Introduction NLP/checkpoints"

ckpt = tf.train.Checkpoint(transformer=transformer, optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')

# %%
@tf.function
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)

    with tf.GradientTape() as tape:
        predictions, _ = transformer(
            inp, tar_inp,
            True,
            enc_padding_mask,
            combined_mask,
            dec_padding_mask
        )
        loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    train_loss(loss)

# %%
for epoch in range(EPOCHS):
    start = time.time()

    train_loss.reset_states()

    for (batch, (inp, tar)) in enumerate(dataset):
        train_step(inp, tar)

        # 55k samples
        # we display 3 batch results -- 0th, middle and last one (approx)
        # 55k / 64 ~ 858; 858 / 2 = 429
        if batch % 2 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1, batch, train_loss.result()))

    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print ('Saving checkpoint for epoch {} at {}'.format(epoch+1, ckpt_save_path))

    print ('Epoch {} Loss {:.4f}'.format(epoch + 1, train_loss.result()))

    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 7.1491
# Epoch 1 Batch 2 Loss 7.1277
# Epoch 1 Batch 4 Loss 7.1408
# Epoch 1 Batch 6 Loss 7.1637
# Epoch 1 Batch 8 Loss 7.1847
# Epoch 1 Batch 10 Loss 7.1874
# Epoch 1 Batch 12 Loss 7.1908
# Epoch 1 Batch 14 Loss 7.1966
# Epoch 1 Batch 16 Loss 7.1989
# Epoch 1 Batch 18 Loss 7.2027
# Epoch 1 Batch 20 Loss 7.1904
# Epoch 1 Batch 22 Loss 7.1926
# Epoch 1 Batch 24 Loss 7.1882
# Epoch 1 Batch 26 Loss 7.1907
# Epoch 1 Batch 28 Loss 7.1912
# Epoch 1 Batch 30 Loss 7.1887
# Epoch 1 Batch 32 Loss 7.1639
# Epoch 1 Batch 34 Loss 7.1624
# Epoch 1 Batch 36 Loss 7.1654
# Epoch 1 Batch 38 Loss 7.1690
# Epoch 1 Batch 40 Loss 7.1718
# Epoch 1 Batch 42 Loss 7.1734
# Epoch 1 Batch 44 Loss 7.1738
# Epoch 1 Batch 46 Loss 7.1758
# Epoch 1 Batch 48 Loss 7.1783
# Epoch 1 Batch 50 Loss 7.1817
# Epoch 1 Batch 52 Loss 7.1820
# Epoch 1 Batch 54 Loss 7.1842
# Epoch 1 Batch 56 Loss 7.1840
# Epoch 1 Batch 58 Loss 7.1829
# Epoch 1 Batch 60 Loss 7.1804
# Epoch 1 Batch 62 Loss 7.1841
# Epoch 1 Batch 64 Loss 7.1847
# Epoch 1 Batch 66 Loss 7.1875
# Epoch 1 Batch 68 Loss 7.1890
# Epoch 1 Batch 70 Loss 7.1882
# Epoch 1 Batch 72 Loss 7.1912
# Epoch 1 Batch 74 Loss 7.1912
# Epoch 1 Batch 76 Loss 7.1904
# Epoch 1 Batch 78 Loss 7.1910
# Epoch 1 Batch 80 Loss 7.1949
# Epoch 1 Batch 82 Loss 7.1943
# Epoch 1 Batch 84 Loss 7.1939
# Epoch 1 Batch 86 Loss 7.1946
# Epoch 1 Batch 88 Loss 7.1933
# Epoch 1 Batch 90 Loss 7.1937
# Epoch 1 Batch 92 Loss 7.1941
# Epoch 1 Batch 94 Loss 7.1954
# Epoch 1 Batch 96 Loss 7.1947
# Epoch 1 Batch 98 Loss 7.1959
# Epoch 1 Loss 7.1962
# Time taken for 1 epoch: 29.335203886032104 secs
#
# Epoch 2 Batch 0 Loss 7.2725
# Epoch 2 Batch 2 Loss 7.2255
# Epoch 2 Batch 4 Loss 7.2183
# Epoch 2 Batch 6 Loss 7.2257
# Epoch 2 Batch 8 Loss 7.1414
# Epoch 2 Batch 10 Loss 7.1413
# Epoch 2 Batch 12 Loss 7.1495
# Epoch 2 Batch 14 Loss 7.1505
# Epoch 2 Batch 16 Loss 7.1571
# Epoch 2 Batch 18 Loss 7.1648
# Epoch 2 Batch 20 Loss 7.1642
# Epoch 2 Batch 22 Loss 7.1732
# Epoch 2 Batch 24 Loss 7.1725
# Epoch 2 Batch 26 Loss 7.1753
# Epoch 2 Batch 28 Loss 7.1751
# Epoch 2 Batch 30 Loss 7.1774
# Epoch 2 Batch 32 Loss 7.1885
# Epoch 2 Batch 34 Loss 7.1845
# Epoch 2 Batch 36 Loss 7.1883
# Epoch 2 Batch 38 Loss 7.1909
# Epoch 2 Batch 40 Loss 7.1970
# Epoch 2 Batch 42 Loss 7.2004
# Epoch 2 Batch 44 Loss 7.2010
# Epoch 2 Batch 46 Loss 7.1991
# Epoch 2 Batch 48 Loss 7.2007
# Epoch 2 Batch 50 Loss 7.1973
# Epoch 2 Batch 52 Loss 7.1991
# Epoch 2 Batch 54 Loss 7.2003
# Epoch 2 Batch 56 Loss 7.1998
# Epoch 2 Batch 58 Loss 7.2013
# Epoch 2 Batch 60 Loss 7.2027
# Epoch 2 Batch 62 Loss 7.2021
# Epoch 2 Batch 64 Loss 7.2019
# Epoch 2 Batch 66 Loss 7.2026
# Epoch 2 Batch 68 Loss 7.2057
# Epoch 2 Batch 70 Loss 7.2061
# Epoch 2 Batch 72 Loss 7.2062
# Epoch 2 Batch 74 Loss 7.2079
# Epoch 2 Batch 76 Loss 7.2058
# Epoch 2 Batch 78 Loss 7.2071
# Epoch 2 Batch 80 Loss 7.2074
# Epoch 2 Batch 82 Loss 7.2047
# Epoch 2 Batch 84 Loss 7.2059
# Epoch 2 Batch 86 Loss 7.2045
# Epoch 2 Batch 88 Loss 7.2021
# Epoch 2 Batch 90 Loss 7.2036
# Epoch 2 Batch 92 Loss 7.2038
# Epoch 2 Batch 94 Loss 7.2035
# Epoch 2 Batch 96 Loss 7.2045
# Epoch 2 Batch 98 Loss 7.2044
# Epoch 2 Loss 7.2042
# Time taken for 1 epoch: 22.835060596466064 secs
#
# Epoch 3 Batch 0 Loss 7.1085
# Epoch 3 Batch 2 Loss 7.1984
# Epoch 3 Batch 4 Loss 7.2077
# Epoch 3 Batch 6 Loss 7.2198
# Epoch 3 Batch 8 Loss 7.2260
# Epoch 3 Batch 10 Loss 7.2418
# Epoch 3 Batch 12 Loss 7.2415
# Epoch 3 Batch 14 Loss 7.2337
# Epoch 3 Batch 16 Loss 7.2199
# Epoch 3 Batch 18 Loss 7.2293
# Epoch 3 Batch 20 Loss 7.2189
# Epoch 3 Batch 22 Loss 7.2178
# Epoch 3 Batch 24 Loss 7.2198
# Epoch 3 Batch 26 Loss 7.2245
# Epoch 3 Batch 28 Loss 7.2239
# Epoch 3 Batch 30 Loss 7.2278
# Epoch 3 Batch 32 Loss 7.2247
# Epoch 3 Batch 34 Loss 7.2199
# Epoch 3 Batch 36 Loss 7.2223
# Epoch 3 Batch 38 Loss 7.2229
# Epoch 3 Batch 40 Loss 7.2213
# Epoch 3 Batch 42 Loss 7.2209
# Epoch 3 Batch 44 Loss 7.2210
# Epoch 3 Batch 46 Loss 7.2191
# Epoch 3 Batch 48 Loss 7.2197
# Epoch 3 Batch 50 Loss 7.2237
# Epoch 3 Batch 52 Loss 7.2200
# Epoch 3 Batch 54 Loss 7.2179
# Epoch 3 Batch 56 Loss 7.2198
# Epoch 3 Batch 58 Loss 7.2204
# Epoch 3 Batch 60 Loss 7.2199
# Epoch 3 Batch 62 Loss 7.2181
# Epoch 3 Batch 64 Loss 7.2186
# Epoch 3 Batch 66 Loss 7.2182
# Epoch 3 Batch 68 Loss 7.2168
# Epoch 3 Batch 70 Loss 7.2058
# Epoch 3 Batch 72 Loss 7.2056
# Epoch 3 Batch 74 Loss 7.2074
# Epoch 3 Batch 76 Loss 7.2094
# Epoch 3 Batch 78 Loss 7.2101
# Epoch 3 Batch 80 Loss 7.2070
# Epoch 3 Batch 82 Loss 7.2077
# Epoch 3 Batch 84 Loss 7.2069
# Epoch 3 Batch 86 Loss 7.2077
# Epoch 3 Batch 88 Loss 7.2079
# Epoch 3 Batch 90 Loss 7.2059
# Epoch 3 Batch 92 Loss 7.2029
# Epoch 3 Batch 94 Loss 7.2045
# Epoch 3 Batch 96 Loss 7.2056
# Epoch 3 Batch 98 Loss 7.2053
# Epoch 3 Loss 7.2039
# Time taken for 1 epoch: 22.952589750289917 secs
#
# Epoch 4 Batch 0 Loss 7.2866
# Epoch 4 Batch 2 Loss 6.9674
# Epoch 4 Batch 4 Loss 7.0508
# Epoch 4 Batch 6 Loss 7.1190
# Epoch 4 Batch 8 Loss 7.1261
# Epoch 4 Batch 10 Loss 7.1298
# Epoch 4 Batch 12 Loss 7.1427
# Epoch 4 Batch 14 Loss 7.1449
# Epoch 4 Batch 16 Loss 7.1472
# Epoch 4 Batch 18 Loss 7.1610
# Epoch 4 Batch 20 Loss 7.1617
# Epoch 4 Batch 22 Loss 7.1590
# Epoch 4 Batch 24 Loss 7.1613
# Epoch 4 Batch 26 Loss 7.1637
# Epoch 4 Batch 28 Loss 7.1697
# Epoch 4 Batch 30 Loss 7.1726
# Epoch 4 Batch 32 Loss 7.1752
# Epoch 4 Batch 34 Loss 7.1793
# Epoch 4 Batch 36 Loss 7.1799
# Epoch 4 Batch 38 Loss 7.1778
# Epoch 4 Batch 40 Loss 7.1807
# Epoch 4 Batch 42 Loss 7.1827
# Epoch 4 Batch 44 Loss 7.1861
# Epoch 4 Batch 46 Loss 7.1879
# Epoch 4 Batch 48 Loss 7.1886
# Epoch 4 Batch 50 Loss 7.1884
# Epoch 4 Batch 52 Loss 7.1896
# Epoch 4 Batch 54 Loss 7.1867
# Epoch 4 Batch 56 Loss 7.1853
# Epoch 4 Batch 58 Loss 7.1843
# Epoch 4 Batch 60 Loss 7.1845
# Epoch 4 Batch 62 Loss 7.1869
# Epoch 4 Batch 64 Loss 7.1880
# Epoch 4 Batch 66 Loss 7.1896
# Epoch 4 Batch 68 Loss 7.1899
# Epoch 4 Batch 70 Loss 7.1904
# Epoch 4 Batch 72 Loss 7.1910
# Epoch 4 Batch 74 Loss 7.1885
# Epoch 4 Batch 76 Loss 7.1914
# Epoch 4 Batch 78 Loss 7.1930
# Epoch 4 Batch 80 Loss 7.1934
# Epoch 4 Batch 82 Loss 7.1946
# Epoch 4 Batch 84 Loss 7.1938
# Epoch 4 Batch 86 Loss 7.1929
# Epoch 4 Batch 88 Loss 7.1933
# Epoch 4 Batch 90 Loss 7.1965
# Epoch 4 Batch 92 Loss 7.1960
# Epoch 4 Batch 94 Loss 7.1967
# Epoch 4 Batch 96 Loss 7.1986
# Epoch 4 Batch 98 Loss 7.1991
# Epoch 4 Loss 7.1987
# Time taken for 1 epoch: 23.025540590286255 secs
#
# Epoch 5 Batch 0 Loss 7.2533
# Epoch 5 Batch 2 Loss 7.1546
# Epoch 5 Batch 4 Loss 7.1633
# Epoch 5 Batch 6 Loss 7.1631
# Epoch 5 Batch 8 Loss 7.1619
# Epoch 5 Batch 10 Loss 7.1887
# Epoch 5 Batch 12 Loss 7.2011
# Epoch 5 Batch 14 Loss 7.2164
# Epoch 5 Batch 16 Loss 7.2206
# Epoch 5 Batch 18 Loss 7.2103
# Epoch 5 Batch 20 Loss 7.2082
# Epoch 5 Batch 22 Loss 7.2125
# Epoch 5 Batch 24 Loss 7.2190
# Epoch 5 Batch 26 Loss 7.2196
# Epoch 5 Batch 28 Loss 7.2169
# Epoch 5 Batch 30 Loss 7.2113
# Epoch 5 Batch 32 Loss 7.2082
# Epoch 5 Batch 34 Loss 7.1832
# Epoch 5 Batch 36 Loss 7.1832
# Epoch 5 Batch 38 Loss 7.1844
# Epoch 5 Batch 40 Loss 7.1872
# Epoch 5 Batch 42 Loss 7.1885
# Epoch 5 Batch 44 Loss 7.1870
# Epoch 5 Batch 46 Loss 7.1865
# Epoch 5 Batch 48 Loss 7.1860
# Epoch 5 Batch 50 Loss 7.1898
# Epoch 5 Batch 52 Loss 7.1871
# Epoch 5 Batch 54 Loss 7.1871
# Epoch 5 Batch 56 Loss 7.1879
# Epoch 5 Batch 58 Loss 7.1891
# Epoch 5 Batch 60 Loss 7.1891
# Epoch 5 Batch 62 Loss 7.1887
# Epoch 5 Batch 64 Loss 7.1896
# Epoch 5 Batch 66 Loss 7.1911
# Epoch 5 Batch 68 Loss 7.1941
# Epoch 5 Batch 70 Loss 7.1963
# Epoch 5 Batch 72 Loss 7.1954
# Epoch 5 Batch 74 Loss 7.1957
# Epoch 5 Batch 76 Loss 7.1959
# Epoch 5 Batch 78 Loss 7.1961
# Epoch 5 Batch 80 Loss 7.1987
# Epoch 5 Batch 82 Loss 7.1992
# Epoch 5 Batch 84 Loss 7.1994
# Epoch 5 Batch 86 Loss 7.1999
# Epoch 5 Batch 88 Loss 7.1998
# Epoch 5 Batch 90 Loss 7.1998
# Epoch 5 Batch 92 Loss 7.2006
# Epoch 5 Batch 94 Loss 7.1992
# Epoch 5 Batch 96 Loss 7.1991
# Epoch 5 Batch 98 Loss 7.2011
# Saving checkpoint for epoch 5 at /content/drive/MyDrive/Phenikaa University/Introduction NLP/checkpoints/ckpt-1
# Epoch 5 Loss 7.2020
# Time taken for 1 epoch: 23.680871963500977 secs
#
# Epoch 6 Batch 0 Loss 7.1255
# Epoch 6 Batch 2 Loss 7.0775
# Epoch 6 Batch 4 Loss 7.1276
# Epoch 6 Batch 6 Loss 7.1596
# Epoch 6 Batch 8 Loss 7.1801
# Epoch 6 Batch 10 Loss 7.1793
# Epoch 6 Batch 12 Loss 7.1815
# Epoch 6 Batch 14 Loss 7.1809
# Epoch 6 Batch 16 Loss 7.1824
# Epoch 6 Batch 18 Loss 7.1857
# Epoch 6 Batch 20 Loss 7.1842
# Epoch 6 Batch 22 Loss 7.1818
# Epoch 6 Batch 24 Loss 7.1798
# Epoch 6 Batch 26 Loss 7.1824
# Epoch 6 Batch 28 Loss 7.1846
# Epoch 6 Batch 30 Loss 7.1840
# Epoch 6 Batch 32 Loss 7.1875
# Epoch 6 Batch 34 Loss 7.1826
# Epoch 6 Batch 36 Loss 7.1871
# Epoch 6 Batch 38 Loss 7.1857
# Epoch 6 Batch 40 Loss 7.1881
# Epoch 6 Batch 42 Loss 7.1914
# Epoch 6 Batch 44 Loss 7.1741
# Epoch 6 Batch 46 Loss 7.1760
# Epoch 6 Batch 48 Loss 7.1752
# Epoch 6 Batch 50 Loss 7.1724
# Epoch 6 Batch 52 Loss 7.1744
# Epoch 6 Batch 54 Loss 7.1753
# Epoch 6 Batch 56 Loss 7.1779
# Epoch 6 Batch 58 Loss 7.1781
# Epoch 6 Batch 60 Loss 7.1787
# Epoch 6 Batch 62 Loss 7.1825
# Epoch 6 Batch 64 Loss 7.1840
# Epoch 6 Batch 66 Loss 7.1847
# Epoch 6 Batch 68 Loss 7.1854
# Epoch 6 Batch 70 Loss 7.1867
# Epoch 6 Batch 72 Loss 7.1880
# Epoch 6 Batch 74 Loss 7.1901
# Epoch 6 Batch 76 Loss 7.1912
# Epoch 6 Batch 78 Loss 7.1920
# Epoch 6 Batch 80 Loss 7.1917
# Epoch 6 Batch 82 Loss 7.1936
# Epoch 6 Batch 84 Loss 7.1944
# Epoch 6 Batch 86 Loss 7.1965
# Epoch 6 Batch 88 Loss 7.1979
# Epoch 6 Batch 90 Loss 7.1973
# Epoch 6 Batch 92 Loss 7.1979
# Epoch 6 Batch 94 Loss 7.1984
# Epoch 6 Batch 96 Loss 7.1979
# Epoch 6 Batch 98 Loss 7.1999
# Epoch 6 Loss 7.2007
# Time taken for 1 epoch: 23.21190094947815 secs
#
# Epoch 7 Batch 0 Loss 7.3340
# Epoch 7 Batch 2 Loss 7.2332
# Epoch 7 Batch 4 Loss 7.2414
# Epoch 7 Batch 6 Loss 7.2341
# Epoch 7 Batch 8 Loss 7.2310
# Epoch 7 Batch 10 Loss 7.2331
# Epoch 7 Batch 12 Loss 7.2260
# Epoch 7 Batch 14 Loss 7.2135
# Epoch 7 Batch 16 Loss 7.2131
# Epoch 7 Batch 18 Loss 7.2126
# Epoch 7 Batch 20 Loss 7.2174
# Epoch 7 Batch 22 Loss 7.2174
# Epoch 7 Batch 24 Loss 7.2090
# Epoch 7 Batch 26 Loss 7.2119
# Epoch 7 Batch 28 Loss 7.2121
# Epoch 7 Batch 30 Loss 7.2122
# Epoch 7 Batch 32 Loss 7.2167
# Epoch 7 Batch 34 Loss 7.2134
# Epoch 7 Batch 36 Loss 7.2079
# Epoch 7 Batch 38 Loss 7.2095
# Epoch 7 Batch 40 Loss 7.2090
# Epoch 7 Batch 42 Loss 7.2094
# Epoch 7 Batch 44 Loss 7.2095
# Epoch 7 Batch 46 Loss 7.2110
# Epoch 7 Batch 48 Loss 7.2079
# Epoch 7 Batch 50 Loss 7.2064
# Epoch 7 Batch 52 Loss 7.2063
# Epoch 7 Batch 54 Loss 7.2063
# Epoch 7 Batch 56 Loss 7.2063
# Epoch 7 Batch 58 Loss 7.2082
# Epoch 7 Batch 60 Loss 7.2118
# Epoch 7 Batch 62 Loss 7.2162
# Epoch 7 Batch 64 Loss 7.2161
# Epoch 7 Batch 66 Loss 7.2176
# Epoch 7 Batch 68 Loss 7.2183
# Epoch 7 Batch 70 Loss 7.2201
# Epoch 7 Batch 72 Loss 7.2202
# Epoch 7 Batch 74 Loss 7.2196
# Epoch 7 Batch 76 Loss 7.2189
# Epoch 7 Batch 78 Loss 7.2191
# Epoch 7 Batch 80 Loss 7.2175
# Epoch 7 Batch 82 Loss 7.2170
# Epoch 7 Batch 84 Loss 7.2159
# Epoch 7 Batch 86 Loss 7.2155
# Epoch 7 Batch 88 Loss 7.2147
# Epoch 7 Batch 90 Loss 7.2128
# Epoch 7 Batch 92 Loss 7.2123
# Epoch 7 Batch 94 Loss 7.2124
# Epoch 7 Batch 96 Loss 7.2037
# Epoch 7 Batch 98 Loss 7.2024
# Epoch 7 Loss 7.2017
# Time taken for 1 epoch: 23.1418879032135 secs
#
# Epoch 8 Batch 0 Loss 7.2574
# Epoch 8 Batch 2 Loss 7.2767
# Epoch 8 Batch 4 Loss 7.3088
# Epoch 8 Batch 6 Loss 7.2806
# Epoch 8 Batch 8 Loss 7.2696
# Epoch 8 Batch 10 Loss 7.2641
# Epoch 8 Batch 12 Loss 7.2482
# Epoch 8 Batch 14 Loss 7.2392
# Epoch 8 Batch 16 Loss 7.2291
# Epoch 8 Batch 18 Loss 7.2239
# Epoch 8 Batch 20 Loss 7.2111
# Epoch 8 Batch 22 Loss 7.1792
# Epoch 8 Batch 24 Loss 7.1780
# Epoch 8 Batch 26 Loss 7.1748
# Epoch 8 Batch 28 Loss 7.1762
# Epoch 8 Batch 30 Loss 7.1733
# Epoch 8 Batch 32 Loss 7.1745
# Epoch 8 Batch 34 Loss 7.1788
# Epoch 8 Batch 36 Loss 7.1804
# Epoch 8 Batch 38 Loss 7.1848
# Epoch 8 Batch 40 Loss 7.1867
# Epoch 8 Batch 42 Loss 7.1902
# Epoch 8 Batch 44 Loss 7.1894
# Epoch 8 Batch 46 Loss 7.1934
# Epoch 8 Batch 48 Loss 7.1954
# Epoch 8 Batch 50 Loss 7.1925
# Epoch 8 Batch 52 Loss 7.1916
# Epoch 8 Batch 54 Loss 7.1938
# Epoch 8 Batch 56 Loss 7.1936
# Epoch 8 Batch 58 Loss 7.1936
# Epoch 8 Batch 60 Loss 7.1947
# Epoch 8 Batch 62 Loss 7.1963
# Epoch 8 Batch 64 Loss 7.1976
# Epoch 8 Batch 66 Loss 7.1978
# Epoch 8 Batch 68 Loss 7.1982
# Epoch 8 Batch 70 Loss 7.1958
# Epoch 8 Batch 72 Loss 7.1959
# Epoch 8 Batch 74 Loss 7.1963
# Epoch 8 Batch 76 Loss 7.1985
# Epoch 8 Batch 78 Loss 7.2006
# Epoch 8 Batch 80 Loss 7.1988
# Epoch 8 Batch 82 Loss 7.1996
# Epoch 8 Batch 84 Loss 7.2009
# Epoch 8 Batch 86 Loss 7.1992
# Epoch 8 Batch 88 Loss 7.1985
# Epoch 8 Batch 90 Loss 7.2008
# Epoch 8 Batch 92 Loss 7.2009
# Epoch 8 Batch 94 Loss 7.2025
# Epoch 8 Batch 96 Loss 7.2032
# Epoch 8 Batch 98 Loss 7.2008
# Epoch 8 Loss 7.2016
# Time taken for 1 epoch: 23.31683850288391 secs
#
# Epoch 9 Batch 0 Loss 7.2996
# Epoch 9 Batch 2 Loss 7.2495
# Epoch 9 Batch 4 Loss 7.2438
# Epoch 9 Batch 6 Loss 7.2416
# Epoch 9 Batch 8 Loss 7.2249
# Epoch 9 Batch 10 Loss 7.2278
# Epoch 9 Batch 12 Loss 7.2227
# Epoch 9 Batch 14 Loss 7.2190
# Epoch 9 Batch 16 Loss 7.2320
# Epoch 9 Batch 18 Loss 7.2329
# Epoch 9 Batch 20 Loss 7.2292
# Epoch 9 Batch 22 Loss 7.2231
# Epoch 9 Batch 24 Loss 7.2230
# Epoch 9 Batch 26 Loss 7.2210
# Epoch 9 Batch 28 Loss 7.2211
# Epoch 9 Batch 30 Loss 7.2237
# Epoch 9 Batch 32 Loss 7.2243
# Epoch 9 Batch 34 Loss 7.2298
# Epoch 9 Batch 36 Loss 7.2318
# Epoch 9 Batch 38 Loss 7.2234
# Epoch 9 Batch 40 Loss 7.2278
# Epoch 9 Batch 42 Loss 7.2290
# Epoch 9 Batch 44 Loss 7.2276
# Epoch 9 Batch 46 Loss 7.2293
# Epoch 9 Batch 48 Loss 7.2277
# Epoch 9 Batch 50 Loss 7.2255
# Epoch 9 Batch 52 Loss 7.2260
# Epoch 9 Batch 54 Loss 7.2239
# Epoch 9 Batch 56 Loss 7.2220
# Epoch 9 Batch 58 Loss 7.2234
# Epoch 9 Batch 60 Loss 7.2190
# Epoch 9 Batch 62 Loss 7.2191
# Epoch 9 Batch 64 Loss 7.2162
# Epoch 9 Batch 66 Loss 7.2153
# Epoch 9 Batch 68 Loss 7.2108
# Epoch 9 Batch 70 Loss 7.2122
# Epoch 9 Batch 72 Loss 7.2141
# Epoch 9 Batch 74 Loss 7.2121
# Epoch 9 Batch 76 Loss 7.2093
# Epoch 9 Batch 78 Loss 7.2003
# Epoch 9 Batch 80 Loss 7.2014
# Epoch 9 Batch 82 Loss 7.2009
# Epoch 9 Batch 84 Loss 7.2008
# Epoch 9 Batch 86 Loss 7.2011
# Epoch 9 Batch 88 Loss 7.2026
# Epoch 9 Batch 90 Loss 7.2013
# Epoch 9 Batch 92 Loss 7.2015
# Epoch 9 Batch 94 Loss 7.2027
# Epoch 9 Batch 96 Loss 7.2034
# Epoch 9 Batch 98 Loss 7.2039
# Epoch 9 Loss 7.2032
# Time taken for 1 epoch: 23.327176094055176 secs
#
# Epoch 10 Batch 0 Loss 7.2258
# Epoch 10 Batch 2 Loss 7.2171
# Epoch 10 Batch 4 Loss 7.1898
# Epoch 10 Batch 6 Loss 7.1877
# Epoch 10 Batch 8 Loss 7.1920
# Epoch 10 Batch 10 Loss 7.1201
# Epoch 10 Batch 12 Loss 7.1459
# Epoch 10 Batch 14 Loss 7.1531
# Epoch 10 Batch 16 Loss 7.1730
# Epoch 10 Batch 18 Loss 7.1810
# Epoch 10 Batch 20 Loss 7.1844
# Epoch 10 Batch 22 Loss 7.1848
# Epoch 10 Batch 24 Loss 7.1797
# Epoch 10 Batch 26 Loss 7.1804
# Epoch 10 Batch 28 Loss 7.1840
# Epoch 10 Batch 30 Loss 7.1886
# Epoch 10 Batch 32 Loss 7.1868
# Epoch 10 Batch 34 Loss 7.1879
# Epoch 10 Batch 36 Loss 7.1892
# Epoch 10 Batch 38 Loss 7.1849
# Epoch 10 Batch 40 Loss 7.1857
# Epoch 10 Batch 42 Loss 7.1828
# Epoch 10 Batch 44 Loss 7.1866
# Epoch 10 Batch 46 Loss 7.1839
# Epoch 10 Batch 48 Loss 7.1844
# Epoch 10 Batch 50 Loss 7.1859
# Epoch 10 Batch 52 Loss 7.1888
# Epoch 10 Batch 54 Loss 7.1913
# Epoch 10 Batch 56 Loss 7.1913
# Epoch 10 Batch 58 Loss 7.1929
# Epoch 10 Batch 60 Loss 7.1929
# Epoch 10 Batch 62 Loss 7.1930
# Epoch 10 Batch 64 Loss 7.1930
# Epoch 10 Batch 66 Loss 7.1919
# Epoch 10 Batch 68 Loss 7.1939
# Epoch 10 Batch 70 Loss 7.1932
# Epoch 10 Batch 72 Loss 7.1935
# Epoch 10 Batch 74 Loss 7.1940
# Epoch 10 Batch 76 Loss 7.1927
# Epoch 10 Batch 78 Loss 7.1922
# Epoch 10 Batch 80 Loss 7.1932
# Epoch 10 Batch 82 Loss 7.1943
# Epoch 10 Batch 84 Loss 7.1958
# Epoch 10 Batch 86 Loss 7.1960
# Epoch 10 Batch 88 Loss 7.1987
# Epoch 10 Batch 90 Loss 7.2009
# Epoch 10 Batch 92 Loss 7.2017
# Epoch 10 Batch 94 Loss 7.2006
# Epoch 10 Batch 96 Loss 7.2002
# Epoch 10 Batch 98 Loss 7.2007
# Saving checkpoint for epoch 10 at /content/drive/MyDrive/Phenikaa University/Introduction NLP/checkpoints/ckpt-2
# Epoch 10 Loss 7.2015
# Time taken for 1 epoch: 23.80534529685974 secs
#
# Epoch 11 Batch 0 Loss 7.2445
# Epoch 11 Batch 2 Loss 7.2155
# Epoch 11 Batch 4 Loss 7.2062
# Epoch 11 Batch 6 Loss 7.2020
# Epoch 11 Batch 8 Loss 7.2072
# Epoch 11 Batch 10 Loss 7.2143
# Epoch 11 Batch 12 Loss 7.2174
# Epoch 11 Batch 14 Loss 7.1618
# Epoch 11 Batch 16 Loss 7.1646
# Epoch 11 Batch 18 Loss 7.1780
# Epoch 11 Batch 20 Loss 7.1840
# Epoch 11 Batch 22 Loss 7.1789
# Epoch 11 Batch 24 Loss 7.1840
# Epoch 11 Batch 26 Loss 7.1844
# Epoch 11 Batch 28 Loss 7.1815
# Epoch 11 Batch 30 Loss 7.1880
# Epoch 11 Batch 32 Loss 7.1947
# Epoch 11 Batch 34 Loss 7.1935
# Epoch 11 Batch 36 Loss 7.1941
# Epoch 11 Batch 38 Loss 7.1955
# Epoch 11 Batch 40 Loss 7.1954
# Epoch 11 Batch 42 Loss 7.1962
# Epoch 11 Batch 44 Loss 7.1967
# Epoch 11 Batch 46 Loss 7.2023
# Epoch 11 Batch 48 Loss 7.2001
# Epoch 11 Batch 50 Loss 7.2019
# Epoch 11 Batch 52 Loss 7.2001
# Epoch 11 Batch 54 Loss 7.1980
# Epoch 11 Batch 56 Loss 7.2002
# Epoch 11 Batch 58 Loss 7.2037
# Epoch 11 Batch 60 Loss 7.2037
# Epoch 11 Batch 62 Loss 7.2026
# Epoch 11 Batch 64 Loss 7.2050
# Epoch 11 Batch 66 Loss 7.2052
# Epoch 11 Batch 68 Loss 7.2042
# Epoch 11 Batch 70 Loss 7.2068
# Epoch 11 Batch 72 Loss 7.2062
# Epoch 11 Batch 74 Loss 7.2057
# Epoch 11 Batch 76 Loss 7.2035
# Epoch 11 Batch 78 Loss 7.2024
# Epoch 11 Batch 80 Loss 7.1996
# Epoch 11 Batch 82 Loss 7.1989
# Epoch 11 Batch 84 Loss 7.1990
# Epoch 11 Batch 86 Loss 7.2001
# Epoch 11 Batch 88 Loss 7.1975
# Epoch 11 Batch 90 Loss 7.1967
# Epoch 11 Batch 92 Loss 7.1990
# Epoch 11 Batch 94 Loss 7.1993
# Epoch 11 Batch 96 Loss 7.2006
# Epoch 11 Batch 98 Loss 7.1991
# Epoch 11 Loss 7.1983
# Time taken for 1 epoch: 23.33186149597168 secs
#
# Epoch 12 Batch 0 Loss 7.2176
# Epoch 12 Batch 2 Loss 7.1644
# Epoch 12 Batch 4 Loss 7.1401
# Epoch 12 Batch 6 Loss 7.1670
# Epoch 12 Batch 8 Loss 7.1850
# Epoch 12 Batch 10 Loss 7.1937
# Epoch 12 Batch 12 Loss 7.1886
# Epoch 12 Batch 14 Loss 7.2017
# Epoch 12 Batch 16 Loss 7.2060
# Epoch 12 Batch 18 Loss 7.2108
# Epoch 12 Batch 20 Loss 7.2164
# Epoch 12 Batch 22 Loss 7.2156
# Epoch 12 Batch 24 Loss 7.2177
# Epoch 12 Batch 26 Loss 7.2100
# Epoch 12 Batch 28 Loss 7.2084
# Epoch 12 Batch 30 Loss 7.2069
# Epoch 12 Batch 32 Loss 7.2079
# Epoch 12 Batch 34 Loss 7.2088
# Epoch 12 Batch 36 Loss 7.2047
# Epoch 12 Batch 38 Loss 7.2033
# Epoch 12 Batch 40 Loss 7.2059
# Epoch 12 Batch 42 Loss 7.2072
# Epoch 12 Batch 44 Loss 7.2067
# Epoch 12 Batch 46 Loss 7.2058
# Epoch 12 Batch 48 Loss 7.2031
# Epoch 12 Batch 50 Loss 7.2061
# Epoch 12 Batch 52 Loss 7.2054
# Epoch 12 Batch 54 Loss 7.2035
# Epoch 12 Batch 56 Loss 7.2072
# Epoch 12 Batch 58 Loss 7.2074
# Epoch 12 Batch 60 Loss 7.2078
# Epoch 12 Batch 62 Loss 7.2062
# Epoch 12 Batch 64 Loss 7.2073
# Epoch 12 Batch 66 Loss 7.2065
# Epoch 12 Batch 68 Loss 7.2084
# Epoch 12 Batch 70 Loss 7.2092
# Epoch 12 Batch 72 Loss 7.2087
# Epoch 12 Batch 74 Loss 7.2066
# Epoch 12 Batch 76 Loss 7.2057
# Epoch 12 Batch 78 Loss 7.2079
# Epoch 12 Batch 80 Loss 7.2077
# Epoch 12 Batch 82 Loss 7.2051
# Epoch 12 Batch 84 Loss 7.1970
# Epoch 12 Batch 86 Loss 7.1953
# Epoch 12 Batch 88 Loss 7.1964
# Epoch 12 Batch 90 Loss 7.1987
# Epoch 12 Batch 92 Loss 7.1994
# Epoch 12 Batch 94 Loss 7.1994
# Epoch 12 Batch 96 Loss 7.1994
# Epoch 12 Batch 98 Loss 7.1993
# Epoch 12 Loss 7.1986
# Time taken for 1 epoch: 23.302518367767334 secs
#
# Epoch 13 Batch 0 Loss 7.2190
# Epoch 13 Batch 2 Loss 7.2112
# Epoch 13 Batch 4 Loss 7.2384
# Epoch 13 Batch 6 Loss 7.2115
# Epoch 13 Batch 8 Loss 7.2100
# Epoch 13 Batch 10 Loss 7.2066
# Epoch 13 Batch 12 Loss 7.1979
# Epoch 13 Batch 14 Loss 7.2016
# Epoch 13 Batch 16 Loss 7.2087
# Epoch 13 Batch 18 Loss 7.2113
# Epoch 13 Batch 20 Loss 7.2207
# Epoch 13 Batch 22 Loss 7.2225
# Epoch 13 Batch 24 Loss 7.2210
# Epoch 13 Batch 26 Loss 7.2212
# Epoch 13 Batch 28 Loss 7.2227
# Epoch 13 Batch 30 Loss 7.2257
# Epoch 13 Batch 32 Loss 7.2021
# Epoch 13 Batch 34 Loss 7.2032
# Epoch 13 Batch 36 Loss 7.2013
# Epoch 13 Batch 38 Loss 7.1984
# Epoch 13 Batch 40 Loss 7.2039
# Epoch 13 Batch 42 Loss 7.2054
# Epoch 13 Batch 44 Loss 7.2072
# Epoch 13 Batch 46 Loss 7.2043
# Epoch 13 Batch 48 Loss 7.2053
# Epoch 13 Batch 50 Loss 7.2024
# Epoch 13 Batch 52 Loss 7.1983
# Epoch 13 Batch 54 Loss 7.2001
# Epoch 13 Batch 56 Loss 7.2012
# Epoch 13 Batch 58 Loss 7.2007
# Epoch 13 Batch 60 Loss 7.2028
# Epoch 13 Batch 62 Loss 7.2024
# Epoch 13 Batch 64 Loss 7.2059
# Epoch 13 Batch 66 Loss 7.2079
# Epoch 13 Batch 68 Loss 7.2081
# Epoch 13 Batch 70 Loss 7.2078
# Epoch 13 Batch 72 Loss 7.2105
# Epoch 13 Batch 74 Loss 7.2068
# Epoch 13 Batch 76 Loss 7.2056
# Epoch 13 Batch 78 Loss 7.2059
# Epoch 13 Batch 80 Loss 7.2045
# Epoch 13 Batch 82 Loss 7.2045
# Epoch 13 Batch 84 Loss 7.2047
# Epoch 13 Batch 86 Loss 7.2036
# Epoch 13 Batch 88 Loss 7.2014
# Epoch 13 Batch 90 Loss 7.2004
# Epoch 13 Batch 92 Loss 7.1989
# Epoch 13 Batch 94 Loss 7.1994
# Epoch 13 Batch 96 Loss 7.1986
# Epoch 13 Batch 98 Loss 7.1985
# Epoch 13 Loss 7.1985
# Time taken for 1 epoch: 23.302464485168457 secs
#
# Epoch 14 Batch 0 Loss 7.1794
# Epoch 14 Batch 2 Loss 7.1784
# Epoch 14 Batch 4 Loss 7.1663
# Epoch 14 Batch 6 Loss 7.2052
# Epoch 14 Batch 8 Loss 7.2062
# Epoch 14 Batch 10 Loss 7.2068
# Epoch 14 Batch 12 Loss 7.2144
# Epoch 14 Batch 14 Loss 7.2098
# Epoch 14 Batch 16 Loss 7.2076
# Epoch 14 Batch 18 Loss 7.2134
# Epoch 14 Batch 20 Loss 7.2093
# Epoch 14 Batch 22 Loss 7.2107
# Epoch 14 Batch 24 Loss 7.2086
# Epoch 14 Batch 26 Loss 7.2049
# Epoch 14 Batch 28 Loss 7.2026
# Epoch 14 Batch 30 Loss 7.2039
# Epoch 14 Batch 32 Loss 7.2092
# Epoch 14 Batch 34 Loss 7.2123
# Epoch 14 Batch 36 Loss 7.2150
# Epoch 14 Batch 38 Loss 7.2134
# Epoch 14 Batch 40 Loss 7.2124
# Epoch 14 Batch 42 Loss 7.2098
# Epoch 14 Batch 44 Loss 7.2077
# Epoch 14 Batch 46 Loss 7.2094
# Epoch 14 Batch 48 Loss 7.2085
# Epoch 14 Batch 50 Loss 7.2090
# Epoch 14 Batch 52 Loss 7.2067
# Epoch 14 Batch 54 Loss 7.2090
# Epoch 14 Batch 56 Loss 7.2076
# Epoch 14 Batch 58 Loss 7.2089
# Epoch 14 Batch 60 Loss 7.2101
# Epoch 14 Batch 62 Loss 7.2086
# Epoch 14 Batch 64 Loss 7.2079
# Epoch 14 Batch 66 Loss 7.2094
# Epoch 14 Batch 68 Loss 7.2081
# Epoch 14 Batch 70 Loss 7.2095
# Epoch 14 Batch 72 Loss 7.2101
# Epoch 14 Batch 74 Loss 7.2102
# Epoch 14 Batch 76 Loss 7.1996
# Epoch 14 Batch 78 Loss 7.2002
# Epoch 14 Batch 80 Loss 7.2009
# Epoch 14 Batch 82 Loss 7.2019
# Epoch 14 Batch 84 Loss 7.2016
# Epoch 14 Batch 86 Loss 7.2012
# Epoch 14 Batch 88 Loss 7.2009
# Epoch 14 Batch 90 Loss 7.2019
# Epoch 14 Batch 92 Loss 7.2011
# Epoch 14 Batch 94 Loss 7.2012
# Epoch 14 Batch 96 Loss 7.2014
# Epoch 14 Batch 98 Loss 7.2034
# Epoch 14 Loss 7.2022
# Time taken for 1 epoch: 23.319371461868286 secs
#
# Epoch 15 Batch 0 Loss 6.4826
# Epoch 15 Batch 2 Loss 7.0134
# Epoch 15 Batch 4 Loss 7.0986
# Epoch 15 Batch 6 Loss 7.1384
# Epoch 15 Batch 8 Loss 7.1523
# Epoch 15 Batch 10 Loss 7.1527
# Epoch 15 Batch 12 Loss 7.1584
# Epoch 15 Batch 14 Loss 7.1720
# Epoch 15 Batch 16 Loss 7.1878
# Epoch 15 Batch 18 Loss 7.1916
# Epoch 15 Batch 20 Loss 7.1940
# Epoch 15 Batch 22 Loss 7.1919
# Epoch 15 Batch 24 Loss 7.1856
# Epoch 15 Batch 26 Loss 7.1923
# Epoch 15 Batch 28 Loss 7.1961
# Epoch 15 Batch 30 Loss 7.1938
# Epoch 15 Batch 32 Loss 7.1965
# Epoch 15 Batch 34 Loss 7.2018
# Epoch 15 Batch 36 Loss 7.1950
# Epoch 15 Batch 38 Loss 7.1945
# Epoch 15 Batch 40 Loss 7.1927
# Epoch 15 Batch 42 Loss 7.1905
# Epoch 15 Batch 44 Loss 7.1889
# Epoch 15 Batch 46 Loss 7.1904
# Epoch 15 Batch 48 Loss 7.1937
# Epoch 15 Batch 50 Loss 7.1984
# Epoch 15 Batch 52 Loss 7.2022
# Epoch 15 Batch 54 Loss 7.1987
# Epoch 15 Batch 56 Loss 7.2012
# Epoch 15 Batch 58 Loss 7.2028
# Epoch 15 Batch 60 Loss 7.2051
# Epoch 15 Batch 62 Loss 7.2050
# Epoch 15 Batch 64 Loss 7.2071
# Epoch 15 Batch 66 Loss 7.2103
# Epoch 15 Batch 68 Loss 7.2092
# Epoch 15 Batch 70 Loss 7.2077
# Epoch 15 Batch 72 Loss 7.2098
# Epoch 15 Batch 74 Loss 7.2079
# Epoch 15 Batch 76 Loss 7.2058
# Epoch 15 Batch 78 Loss 7.2045
# Epoch 15 Batch 80 Loss 7.2044
# Epoch 15 Batch 82 Loss 7.2038
# Epoch 15 Batch 84 Loss 7.2043
# Epoch 15 Batch 86 Loss 7.2053
# Epoch 15 Batch 88 Loss 7.2054
# Epoch 15 Batch 90 Loss 7.2049
# Epoch 15 Batch 92 Loss 7.2042
# Epoch 15 Batch 94 Loss 7.2039
# Epoch 15 Batch 96 Loss 7.2030
# Epoch 15 Batch 98 Loss 7.2020
# Saving checkpoint for epoch 15 at /content/drive/MyDrive/Phenikaa University/Introduction NLP/checkpoints/ckpt-3
# Epoch 15 Loss 7.2018
# Time taken for 1 epoch: 23.86580538749695 secs
#
# Epoch 16 Batch 0 Loss 7.2546
# Epoch 16 Batch 2 Loss 7.2477
# Epoch 16 Batch 4 Loss 7.2170
# Epoch 16 Batch 6 Loss 7.2210
# Epoch 16 Batch 8 Loss 7.2175
# Epoch 16 Batch 10 Loss 7.2125
# Epoch 16 Batch 12 Loss 7.2074
# Epoch 16 Batch 14 Loss 7.1909
# Epoch 16 Batch 16 Loss 7.1833
# Epoch 16 Batch 18 Loss 7.1896
# Epoch 16 Batch 20 Loss 7.1785
# Epoch 16 Batch 22 Loss 7.1813
# Epoch 16 Batch 24 Loss 7.1882
# Epoch 16 Batch 26 Loss 7.1891
# Epoch 16 Batch 28 Loss 7.1851
# Epoch 16 Batch 30 Loss 7.1847
# Epoch 16 Batch 32 Loss 7.1884
# Epoch 16 Batch 34 Loss 7.1915
# Epoch 16 Batch 36 Loss 7.1912
# Epoch 16 Batch 38 Loss 7.1936
# Epoch 16 Batch 40 Loss 7.1944
# Epoch 16 Batch 42 Loss 7.1959
# Epoch 16 Batch 44 Loss 7.1983
# Epoch 16 Batch 46 Loss 7.1995
# Epoch 16 Batch 48 Loss 7.2035
# Epoch 16 Batch 50 Loss 7.2049
# Epoch 16 Batch 52 Loss 7.2036
# Epoch 16 Batch 54 Loss 7.2040
# Epoch 16 Batch 56 Loss 7.2031
# Epoch 16 Batch 58 Loss 7.2033
# Epoch 16 Batch 60 Loss 7.2024
# Epoch 16 Batch 62 Loss 7.2054
# Epoch 16 Batch 64 Loss 7.2043
# Epoch 16 Batch 66 Loss 7.2052
# Epoch 16 Batch 68 Loss 7.2064
# Epoch 16 Batch 70 Loss 7.2068
# Epoch 16 Batch 72 Loss 7.2053
# Epoch 16 Batch 74 Loss 7.2040
# Epoch 16 Batch 76 Loss 7.2017
# Epoch 16 Batch 78 Loss 7.2055
# Epoch 16 Batch 80 Loss 7.2046
# Epoch 16 Batch 82 Loss 7.2036
# Epoch 16 Batch 84 Loss 7.2053
# Epoch 16 Batch 86 Loss 7.2055
# Epoch 16 Batch 88 Loss 7.2056
# Epoch 16 Batch 90 Loss 7.2076
# Epoch 16 Batch 92 Loss 7.1996
# Epoch 16 Batch 94 Loss 7.1986
# Epoch 16 Batch 96 Loss 7.1998
# Epoch 16 Batch 98 Loss 7.2003
# Epoch 16 Loss 7.2000
# Time taken for 1 epoch: 23.292152404785156 secs
#
# Epoch 17 Batch 0 Loss 7.1873
# Epoch 17 Batch 2 Loss 7.1742
# Epoch 17 Batch 4 Loss 7.2294
# Epoch 17 Batch 6 Loss 7.2074
# Epoch 17 Batch 8 Loss 7.2179
# Epoch 17 Batch 10 Loss 7.2182
# Epoch 17 Batch 12 Loss 7.2162
# Epoch 17 Batch 14 Loss 7.2142
# Epoch 17 Batch 16 Loss 7.2104
# Epoch 17 Batch 18 Loss 7.2115
# Epoch 17 Batch 20 Loss 7.2063
# Epoch 17 Batch 22 Loss 7.2119
# Epoch 17 Batch 24 Loss 7.2115
# Epoch 17 Batch 26 Loss 7.2140
# Epoch 17 Batch 28 Loss 7.2110
# Epoch 17 Batch 30 Loss 7.2036
# Epoch 17 Batch 32 Loss 7.2038
# Epoch 17 Batch 34 Loss 7.2045
# Epoch 17 Batch 36 Loss 7.2014
# Epoch 17 Batch 38 Loss 7.2064
# Epoch 17 Batch 40 Loss 7.2068
# Epoch 17 Batch 42 Loss 7.2032
# Epoch 17 Batch 44 Loss 7.2021
# Epoch 17 Batch 46 Loss 7.2035
# Epoch 17 Batch 48 Loss 7.2050
# Epoch 17 Batch 50 Loss 7.2057
# Epoch 17 Batch 52 Loss 7.2042
# Epoch 17 Batch 54 Loss 7.2044
# Epoch 17 Batch 56 Loss 7.2029
# Epoch 17 Batch 58 Loss 7.2024
# Epoch 17 Batch 60 Loss 7.2009
# Epoch 17 Batch 62 Loss 7.2006
# Epoch 17 Batch 64 Loss 7.2002
# Epoch 17 Batch 66 Loss 7.2006
# Epoch 17 Batch 68 Loss 7.2019
# Epoch 17 Batch 70 Loss 7.2041
# Epoch 17 Batch 72 Loss 7.2044
# Epoch 17 Batch 74 Loss 7.2040
# Epoch 17 Batch 76 Loss 7.2053
# Epoch 17 Batch 78 Loss 7.2078
# Epoch 17 Batch 80 Loss 7.2058
# Epoch 17 Batch 82 Loss 7.2047
# Epoch 17 Batch 84 Loss 7.2062
# Epoch 17 Batch 86 Loss 7.2057
# Epoch 17 Batch 88 Loss 7.2027
# Epoch 17 Batch 90 Loss 7.2034
# Epoch 17 Batch 92 Loss 7.2059
# Epoch 17 Batch 94 Loss 7.2052
# Epoch 17 Batch 96 Loss 7.2069
# Epoch 17 Batch 98 Loss 7.2003
# Epoch 17 Loss 7.2016
# Time taken for 1 epoch: 23.33132004737854 secs
#
# Epoch 18 Batch 0 Loss 7.1261
# Epoch 18 Batch 2 Loss 7.1196
# Epoch 18 Batch 4 Loss 7.1761
# Epoch 18 Batch 6 Loss 7.2086
# Epoch 18 Batch 8 Loss 7.2083
# Epoch 18 Batch 10 Loss 7.2220
# Epoch 18 Batch 12 Loss 7.2292
# Epoch 18 Batch 14 Loss 7.2192
# Epoch 18 Batch 16 Loss 7.2186
# Epoch 18 Batch 18 Loss 7.2199
# Epoch 18 Batch 20 Loss 7.2211
# Epoch 18 Batch 22 Loss 7.2227
# Epoch 18 Batch 24 Loss 7.2195
# Epoch 18 Batch 26 Loss 7.2259
# Epoch 18 Batch 28 Loss 7.2256
# Epoch 18 Batch 30 Loss 7.2217
# Epoch 18 Batch 32 Loss 7.2246
# Epoch 18 Batch 34 Loss 7.2201
# Epoch 18 Batch 36 Loss 7.2215
# Epoch 18 Batch 38 Loss 7.2175
# Epoch 18 Batch 40 Loss 7.2132
# Epoch 18 Batch 42 Loss 7.2133
# Epoch 18 Batch 44 Loss 7.2140
# Epoch 18 Batch 46 Loss 7.2098
# Epoch 18 Batch 48 Loss 7.2105
# Epoch 18 Batch 50 Loss 7.2097
# Epoch 18 Batch 52 Loss 7.2064
# Epoch 18 Batch 54 Loss 7.2098
# Epoch 18 Batch 56 Loss 7.2125
# Epoch 18 Batch 58 Loss 7.2135
# Epoch 18 Batch 60 Loss 7.2014
# Epoch 18 Batch 62 Loss 7.2004
# Epoch 18 Batch 64 Loss 7.2000
# Epoch 18 Batch 66 Loss 7.2001
# Epoch 18 Batch 68 Loss 7.1987
# Epoch 18 Batch 70 Loss 7.1982
# Epoch 18 Batch 72 Loss 7.1995
# Epoch 18 Batch 74 Loss 7.1990
# Epoch 18 Batch 76 Loss 7.1993
# Epoch 18 Batch 78 Loss 7.2005
# Epoch 18 Batch 80 Loss 7.2002
# Epoch 18 Batch 82 Loss 7.2000
# Epoch 18 Batch 84 Loss 7.2002
# Epoch 18 Batch 86 Loss 7.2005
# Epoch 18 Batch 88 Loss 7.2022
# Epoch 18 Batch 90 Loss 7.2007
# Epoch 18 Batch 92 Loss 7.2001
# Epoch 18 Batch 94 Loss 7.2000
# Epoch 18 Batch 96 Loss 7.2007
# Epoch 18 Batch 98 Loss 7.2008
# Epoch 18 Loss 7.2012
# Time taken for 1 epoch: 23.28673219680786 secs
#
# Epoch 19 Batch 0 Loss 7.2435
# Epoch 19 Batch 2 Loss 7.2261
# Epoch 19 Batch 4 Loss 7.1843
# Epoch 19 Batch 6 Loss 7.1840
# Epoch 19 Batch 8 Loss 7.1976
# Epoch 19 Batch 10 Loss 7.1944
# Epoch 19 Batch 12 Loss 7.1823
# Epoch 19 Batch 14 Loss 7.1943
# Epoch 19 Batch 16 Loss 7.1975
# Epoch 19 Batch 18 Loss 7.1986
# Epoch 19 Batch 20 Loss 7.1952
# Epoch 19 Batch 22 Loss 7.2013
# Epoch 19 Batch 24 Loss 7.2065
# Epoch 19 Batch 26 Loss 7.1978
# Epoch 19 Batch 28 Loss 7.1971
# Epoch 19 Batch 30 Loss 7.1742
# Epoch 19 Batch 32 Loss 7.1777
# Epoch 19 Batch 34 Loss 7.1811
# Epoch 19 Batch 36 Loss 7.1865
# Epoch 19 Batch 38 Loss 7.1869
# Epoch 19 Batch 40 Loss 7.1878
# Epoch 19 Batch 42 Loss 7.1882
# Epoch 19 Batch 44 Loss 7.1915
# Epoch 19 Batch 46 Loss 7.1972
# Epoch 19 Batch 48 Loss 7.1978
# Epoch 19 Batch 50 Loss 7.1987
# Epoch 19 Batch 52 Loss 7.1979
# Epoch 19 Batch 54 Loss 7.1974
# Epoch 19 Batch 56 Loss 7.1968
# Epoch 19 Batch 58 Loss 7.1972
# Epoch 19 Batch 60 Loss 7.1961
# Epoch 19 Batch 62 Loss 7.1974
# Epoch 19 Batch 64 Loss 7.2002
# Epoch 19 Batch 66 Loss 7.1996
# Epoch 19 Batch 68 Loss 7.1990
# Epoch 19 Batch 70 Loss 7.1989
# Epoch 19 Batch 72 Loss 7.1986
# Epoch 19 Batch 74 Loss 7.1996
# Epoch 19 Batch 76 Loss 7.2033
# Epoch 19 Batch 78 Loss 7.2044
# Epoch 19 Batch 80 Loss 7.2068
# Epoch 19 Batch 82 Loss 7.2043
# Epoch 19 Batch 84 Loss 7.2038
# Epoch 19 Batch 86 Loss 7.2029
# Epoch 19 Batch 88 Loss 7.2041
# Epoch 19 Batch 90 Loss 7.2022
# Epoch 19 Batch 92 Loss 7.2002
# Epoch 19 Batch 94 Loss 7.2008
# Epoch 19 Batch 96 Loss 7.2017
# Epoch 19 Batch 98 Loss 7.2017
# Epoch 19 Loss 7.2029
# Time taken for 1 epoch: 23.30544638633728 secs
#
# Epoch 20 Batch 0 Loss 7.2255
# Epoch 20 Batch 2 Loss 7.2017
# Epoch 20 Batch 4 Loss 7.2594
# Epoch 20 Batch 6 Loss 7.2517
# Epoch 20 Batch 8 Loss 7.2326
# Epoch 20 Batch 10 Loss 7.2412
# Epoch 20 Batch 12 Loss 7.2339
# Epoch 20 Batch 14 Loss 7.2360
# Epoch 20 Batch 16 Loss 7.2381
# Epoch 20 Batch 18 Loss 7.2429
# Epoch 20 Batch 20 Loss 7.2334
# Epoch 20 Batch 22 Loss 7.2268
# Epoch 20 Batch 24 Loss 7.2263
# Epoch 20 Batch 26 Loss 7.2183
# Epoch 20 Batch 28 Loss 7.2187
# Epoch 20 Batch 30 Loss 7.2164
# Epoch 20 Batch 32 Loss 7.2112
# Epoch 20 Batch 34 Loss 7.2150
# Epoch 20 Batch 36 Loss 7.2166
# Epoch 20 Batch 38 Loss 7.2163
# Epoch 20 Batch 40 Loss 7.2147
# Epoch 20 Batch 42 Loss 7.2174
# Epoch 20 Batch 44 Loss 7.2139
# Epoch 20 Batch 46 Loss 7.2143
# Epoch 20 Batch 48 Loss 7.2148
# Epoch 20 Batch 50 Loss 7.2129
# Epoch 20 Batch 52 Loss 7.2100
# Epoch 20 Batch 54 Loss 7.2099
# Epoch 20 Batch 56 Loss 7.2072
# Epoch 20 Batch 58 Loss 7.2066
# Epoch 20 Batch 60 Loss 7.2092
# Epoch 20 Batch 62 Loss 7.2099
# Epoch 20 Batch 64 Loss 7.2121
# Epoch 20 Batch 66 Loss 7.2130
# Epoch 20 Batch 68 Loss 7.2097
# Epoch 20 Batch 70 Loss 7.2087
# Epoch 20 Batch 72 Loss 7.2102
# Epoch 20 Batch 74 Loss 7.2101
# Epoch 20 Batch 76 Loss 7.2093
# Epoch 20 Batch 78 Loss 7.2096
# Epoch 20 Batch 80 Loss 7.2012
# Epoch 20 Batch 82 Loss 7.2022
# Epoch 20 Batch 84 Loss 7.2003
# Epoch 20 Batch 86 Loss 7.2003
# Epoch 20 Batch 88 Loss 7.2010
# Epoch 20 Batch 90 Loss 7.1997
# Epoch 20 Batch 92 Loss 7.1994
# Epoch 20 Batch 94 Loss 7.1996
# Epoch 20 Batch 96 Loss 7.2009
# Epoch 20 Batch 98 Loss 7.2009
# Saving checkpoint for epoch 20 at /content/drive/MyDrive/Phenikaa University/Introduction NLP/checkpoints/ckpt-4
# Epoch 20 Loss 7.2030
# Time taken for 1 epoch: 23.88341760635376 secs

# %%
def evaluate(input_document):
    input_document = document_tokenizer.texts_to_sequences([input_document])
    input_document = tf.keras.preprocessing.sequence.pad_sequences(input_document, maxlen=encoder_maxlen, padding='post', truncating='post')

    encoder_input = tf.expand_dims(input_document[0], 0)

    decoder_input = [summary_tokenizer.word_index["<go>"]]
    output = tf.expand_dims(decoder_input, 0)

    for i in range(decoder_maxlen):
        enc_padding_mask, combined_mask, dec_padding_mask = create_masks(encoder_input, output)

        predictions, attention_weights = transformer(
            encoder_input,
            output,
            False,
            enc_padding_mask,
            combined_mask,
            dec_padding_mask
        )

        predictions = predictions[: ,-1:, :]
        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

        if predicted_id == summary_tokenizer.word_index["<stop>"]:
            return tf.squeeze(output, axis=0), attention_weights

        output = tf.concat([output, predicted_id], axis=-1)

    return tf.squeeze(output, axis=0), attention_weights

# %%
def summarize(input_document):
    # not considering attention weights for now, can be used to plot attention heatmaps in the future
    summarized = evaluate(input_document=input_document)[0].numpy()
    summarized = np.expand_dims(summarized[1:], 0)  # not printing <go> token
    return summary_tokenizer.sequences_to_texts(summarized)[0]  # since there

# %%
summarize(
    "chuyên gia truyền thông trương đức phương có nhiều năm làm việc trong lĩnh vực truyền thông - báo chí và hiện là nhà truyền thông chuyên nghiệp trong lĩnh vực tài chính, bất động sản và y tế"
)
# Out:
# 'trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời trời'
